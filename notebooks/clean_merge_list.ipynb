# %%
# %cd "/gscratch/xlab/alisaliu/hack-tokenizers"
# Out:
# /mmfs1/gscratch/xlab/alisaliu/hack-tokenizers
# /gscratch/cse/alisaliu/miniconda3/envs/playground/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
from utils import read_tokenizer_json, ensure_dir
from pathlib import Path
from tqdm import tqdm
from collections import defaultdict, Counter
from tokenizers import Tokenizer
import seaborn as sns
import numpy as np

# %%
tokenizer_dir = Path('tokenizer_json/llm_tokenizers')

# %%
model_name = 'llama'
tokenizer_json = read_tokenizer_json(tokenizer_dir / f'{model_name}_tokenizer.json')

# %%
# check if merges are unique
rhs = []
for m in tokenizer_json['merges']:
    rhs.append(''.join(m.split(' ')))
print(f'All merges unique: {len(rhs) == len(set(rhs))}')
print(f'Fraction of non-redundant merges: {len(set(rhs))/len(rhs)}')
# Out:
# All merges unique: False
# Fraction of non-redundant merges: 0.4834691178631488

# %% [markdown]
# # If all merges are unique (no cleaning needed)

# %%
merges = tokenizer_json['merges']
ensure_dir(f'data/llm_tokenizers/{model_name}')
with open(f'data/llm_tokenizers/{model_name}/merges.txt', 'w') as fin:
    fin.write('#version: 0.2\n')
    fin.writelines('\n'.join(merges))

# %% [markdown]
# # Else: clean redundant merges

# %%
token_to_rank = {}
for i, m in tqdm(enumerate(tokenizer_json['merges'])):
    merged_token = ''.join(m.split(' '))
    token_to_rank[merged_token] = i
# Out:
# 61249it [00:00, 1051021.27it/s]

# %%
token_to_merges = defaultdict(list)
for m in tokenizer_json['merges']:
    if model_name == 'gemma':
        if any([all([x == y for x in ''.join(m.split(' '))]) for y in ['\t', '\n', '▁']]):
            continue
    token = ''.join(m.split(' '))
    token_to_merges[token].append(m)

# %%
token_to_merges
# Out:
# defaultdict(list,
#             {'▁t': ['▁ t'],
#              'er': ['e r'],
#              'in': ['i n'],
#              '▁a': ['▁ a'],
#              'en': ['e n'],
#              'on': ['o n'],
#              '▁th': ['▁t h', '▁ th'],
#              'es': ['e s'],
#              '▁s': ['▁ s'],
#              '▁d': ['▁ d'],
#              'at': ['a t'],
#              'or': ['o r'],
#              'an': ['a n'],
#              '▁c': ['▁ c'],
#              'is': ['i s'],
#              're': ['r e'],
#              'it': ['i t'],
#              '▁the': ['▁t he', '▁th e', '▁ the'],
#              'ar': ['a r'],
#              'le': ['l e'],
#              '▁w': ['▁ w'],
#              '▁p': ['▁ p'],
#              'ou': ['o u'],
#              'al': ['a l'],
#              '▁f': ['▁ f'],
#              '▁m': ['▁ m'],
#              'ed': ['e d'],
#              '▁o': ['▁ o'],
#              '▁b': ['▁ b'],
#              'om': ['o m'],
#              'ion': ['io n', 'i on'],
#              'ing': ['in g', 'i ng'],
#              'ic': ['i c'],
#              'as': ['a s'],
#              'el': ['e l'],
#              'ent': ['en t', 'e nt'],
#              '▁in': ['▁i n', '▁ in'],
#              '▁h': ['▁ h'],
#              'nd': ['n d'],
#              'et': ['e t'],
#              '▁l': ['▁ l'],
#              '▁n': ['▁ n'],
#              'st': ['s t'],
#              '▁to': ['▁t o', '▁ to'],
#              'ch': ['c h'],
#              '▁I': ['▁ I'],
#              'ro': ['r o'],
#              'il': ['i l'],
#              '▁of': ['▁o f', '▁ of'],
#              'de': ['d e'],
#              'ct': ['c t'],
#              '▁(': ['▁ ('],
#              'am': ['a m'],
#              '▁C': ['▁ C'],
#              '▁de': ['▁d e', '▁ de'],
#              '▁S': ['▁ S'],
#              '▁u': ['▁ u'],
#              '▁A': ['▁ A'],
#              '▁\\': ['▁ \\'],
#              '▁e': ['▁ e'],
#              '▁and': ['▁a nd', '▁an d', '▁ and'],
#              '▁T': ['▁ T'],
#              'ol': ['o l'],
#              '▁v': ['▁ v'],
#              'im': ['i m'],
#              'ot': ['o t'],
#              'ad': ['a d'],
#              'ut': ['u t'],
#              '▁g': ['▁ g'],
#              'em': ['e m'],
#              'ur': ['u r'],
#              'id': ['i d'],
#              '▁*': ['▁ *'],
#              'ig': ['i g'],
#              'ra': ['r a'],
#              '▁re': ['▁r e', '▁ re'],
#              '▁is': ['▁i s', '▁ is'],
#              'qu': ['q u'],
#              'ow': ['o w'],
#              '▁M': ['▁ M'],
#              'est': ['es t', 'e st'],
#              '▁y': ['▁ y'],
#              'se': ['s e'],
#              've': ['v e'],
#              'ce': ['c e'],
#              'ie': ['i e'],
#              'un': ['u n'],
#              '▁P': ['▁ P'],
#              '▁B': ['▁ B'],
#              'ag': ['a g'],
#              'ul': ['u l'],
#              '▁=': ['▁ ='],
#              'he': ['h e'],
#              'end': ['en d', 'e nd'],
#              'ode': ['od e', 'o de'],
#              'ter': ['te r', 't er'],
#              'ment': ['me nt', 'men t', 'm ent'],
#              'os': ['o s'],
#              '▁D': ['▁ D'],
#              'if': ['i f'],
#              'ation': ['at ion', 'ati on', 'atio n', 'a tion'],
#              '▁for': ['▁f or', '▁fo r', '▁ for'],
#              '▁r': ['▁ r'],
#              '▁L': ['▁ L'],
#              '▁you': ['▁y ou', '▁yo u', '▁ you'],
#              '▁be': ['▁b e', '▁ be'],
#              'ly': ['l y'],
#              'ver': ['ve r', 'v er'],
#              'ab': ['a b'],
#              'te': ['t e'],
#              '▁it': ['▁i t', '▁ it'],
#              '▁on': ['▁o n', '▁ on'],
#              'ri': ['r i'],
#              'us': ['u s'],
#              '▁"': ['▁ "'],
#              '▁wh': ['▁w h', '▁ wh'],
#              '▁con': ['▁c on', '▁co n', '▁ con'],
#              '▁H': ['▁ H'],
#              '▁st': ['▁s t', '▁ st'],
#              'ir': ['i r'],
#              '▁E': ['▁ E'],
#              '▁F': ['▁ F'],
#              'ck': ['c k'],
#              '▁an': ['▁a n', '▁ an'],
#              'th': ['t h'],
#              'eg': ['e g'],
#              'ay': ['a y'],
#              'ith': ['it h', 'i th'],
#              '▁R': ['▁ R'],
#              'ist': ['is t', 'i st'],
#              'and': ['an d', 'a nd'],
#              '▁that': ['▁t hat', '▁th at', '▁ that'],
#              '▁al': ['▁a l', '▁ al'],
#              '▁$': ['▁ $'],
#              '▁#': ['▁ #'],
#              'od': ['o d'],
#              'um': ['u m'],
#              '▁W': ['▁ W'],
#              'ht': ['h t'],
#              'code': ['co de', 'cod e', 'c ode'],
#              '▁G': ['▁ G'],
#              'ate': ['at e', 'a te'],
#              'ess': ['es s', 'e ss'],
#              '▁N': ['▁ N'],
#              'ere': ['er e', 'e re'],
#              'pp': ['p p'],
#              '▁as': ['▁a s', '▁ as'],
#              '▁se': ['▁s e', '▁ se'],
#              '▁pro': ['▁p ro', '▁pr o', '▁ pro'],
#              '▁with': ['▁w ith', '▁wit h', '▁ with'],
#              'pe': ['p e'],
#              '▁k': ['▁ k'],
#              'ers': ['er s', 'e rs'],
#              'pt': ['p t'],
#              ');': [') ;'],
#              'lo': ['l o'],
#              '▁com': ['▁c om', '▁co m', '▁ com'],
#              'ame': ['am e', 'a me'],
#              '▁`': ['▁ `'],
#              '▁Com': ['▁C om', '▁Co m', '▁ Com'],
#              'ia': ['i a'],
#              'ant': ['an t', 'a nt'],
#              '▁la': ['▁l a', '▁ la'],
#              '▁{': ['▁ {'],
#              '▁en': ['▁e n', '▁ en'],
#              'ction': ['ct ion', 'c tion'],
#              '▁ex': ['▁e x', '▁ ex'],
#              'ld': ['l d'],
#              'ub': ['u b'],
#              '▁j': ['▁ j'],
#              'la': ['l a'],
#              'ue': ['u e'],
#              '▁J': ['▁ J'],
#              'ich': ['ic h', 'i ch'],
#              '▁do': ['▁d o', '▁ do'],
#              '▁O': ['▁ O'],
#              '▁qu': ['▁q u', '▁ qu'],
#              'iv': ['i v'],
#              'ort': ['or t', 'o rt'],
#              'art': ['ar t', 'a rt'],
#              '▁un': ['▁u n', '▁ un'],
#              '▁##': ['▁# #', '▁ ##'],
#              '▁this': ['▁t his', '▁th is', '▁ this'],
#              'ke': ['k e'],
#              '▁ha': ['▁h a', '▁ ha'],
#              '▁-': ['▁ -'],
#              'out': ['ou t', 'o ut'],
#              '▁The': ['▁T he', '▁Th e', '▁ The'],
#              '▁not': ['▁n ot', '▁no t', '▁ not'],
#              '▁ne': ['▁n e', '▁ ne'],
#              'ill': ['il l', 'i ll'],
#              '▁le': ['▁l e', '▁ le'],
#              'ci': ['c i'],
#              'rom': ['ro m', 'r om'],
#              'ine': ['in e', 'i ne'],
#              '//': ['/ /'],
#              'op': ['o p'],
#              'egin': ['eg in', 'e gin'],
#              '▁Comment': ['▁Com ment', '▁Comm ent', '▁ Comment'],
#              'begin': ['be gin', 'beg in', 'b egin'],
#              'ст': ['с т'],
#              'ass': ['as s', 'a ss'],
#              'iz': ['i z'],
#              ').': [') .'],
#              'og': ['o g'],
#              '▁п': ['▁ п'],
#              '▁or': ['▁o r', '▁ or'],
#              '▁was': ['▁w as', '▁wa s', '▁ was'],
#              '▁at': ['▁a t', '▁ at'],
#              'our': ['ou r', 'o ur'],
#              '▁i': ['▁ i'],
#              'ain': ['ai n', 'a in'],
#              '▁K': ['▁ K'],
#              'на': ['н а'],
#              '▁V': ['▁ V'],
#              'ge': ['g e'],
#              '▁su': ['▁s u', '▁ su'],
#              'ap': ['a p'],
#              'age': ['ag e', 'a ge'],
#              'ould': ['ou ld', 'oul d', 'o uld'],
#              'ne': ['n e'],
#              'av': ['a v'],
#              'xt': ['x t'],
#              'ore': ['or e', 'o re'],
#              'ile': ['il e', 'i le'],
#              '--': ['- -'],
#              '▁в': ['▁ в'],
#              '▁by': ['▁b y', '▁ by'],
#              'li': ['l i'],
#              'ath': ['at h', 'a th'],
#              'ра': ['р а'],
#              'ber': ['be r', 'b er'],
#              'ach': ['ac h', 'a ch'],
#              'all': ['al l', 'a ll'],
#              '▁Th': ['▁T h', '▁ Th'],
#              'ult': ['ul t', 'u lt'],
#              '▁}': ['▁ }'],
#              '▁U': ['▁ U'],
#              '▁us': ['▁u s', '▁ us'],
#              '▁z': ['▁ z'],
#              'ust': ['us t', 'u st'],
#              '▁have': ['▁h ave', '▁ha ve', '▁hav e', '▁ have'],
#              'lic': ['li c', 'l ic'],
#              'ни': ['н и'],
#              '▁can': ['▁c an', '▁ca n', '▁ can'],
#              'tr': ['t r'],
#              'com': ['co m', 'c om'],
#              '),': [') ,'],
#              '▁In': ['▁I n', '▁ In'],
#              'ind': ['in d', 'i nd'],
#              'ell': ['el l', 'e ll'],
#              '▁from': ['▁f rom', '▁fr om', '▁fro m', '▁ from'],
#              'ов': ['о в'],
#              'to': ['t o'],
#              '▁[': ['▁ ['],
#              'able': ['ab le', 'abl e', 'a ble'],
#              'ost': ['os t', 'o st'],
#              '▁ch': ['▁c h', '▁ ch'],
#              'ect': ['ec t', 'e ct'],
#              'ight': ['ig ht', 'igh t'],
#              'int': ['in t', 'i nt'],
#              "▁'": ["▁ '"],
#              '▁are': ['▁a re', '▁ar e', '▁ are'],
#              '▁im': ['▁i m', '▁ im'],
#              '▁sh': ['▁s h', '▁ sh'],
#              '▁<': ['▁ <'],
#              '▁An': ['▁A n', '▁ An'],
#              '▁с': ['▁ с'],
#              'ata': ['at a', 'a ta'],
#              'ire': ['ir e', 'i re'],
#              '▁tr': ['▁t r', '▁ tr'],
#              'con': ['co n', 'c on'],
#              'ord': ['or d', 'o rd'],
#              'ity': ['it y', 'i ty'],
#              'ard': ['ar d', 'a rd'],
#              '▁he': ['▁h e', '▁ he'],
#              '▁but': ['▁b ut', '▁bu t', '▁ but'],
#              'oc': ['o c'],
#              '="': ['= "'],
#              '▁pr': ['▁p r', '▁ pr'],
#              'ure': ['ur e', 'u re'],
#              'per': ['pe r', 'p er'],
#              'ack': ['ac k', 'a ck'],
#              'ork': ['or k'],
#              'ong': ['on g', 'o ng'],
#              'ans': ['an s', 'a ns'],
#              'ко': ['к о'],
#              'ple': ['pl e', 'p le'],
#              '▁des': ['▁d es', '▁de s', '▁ des'],
#              'ok': ['o k'],
#              'orm': ['or m', 'o rm'],
#              'wer': ['we r', 'w er'],
#              'ak': ['a k'],
#              'pr': ['p r'],
#              'ase': ['as e', 'a se'],
#              '▁el': ['▁e l', '▁ el'],
#              'ph': ['p h'],
#              'ac': ['a c'],
#              '▁und': ['▁u nd', '▁un d', '▁ und'],
#              '▁ar': ['▁a r', '▁ ar'],
#              '▁if': ['▁i f', '▁ if'],
#              'ud': ['u d'],
#              'ps': ['p s'],
#              'ite': ['it e', 'i te'],
#              'ble': ['bl e', 'b le'],
#              'но': ['н о'],
#              'fer': ['fe r', 'f er'],
#              'pl': ['p l'],
#              'ive': ['iv e', 'i ve'],
#              'ang': ['an g', 'a ng'],
#              'ens': ['en s', 'e ns'],
#              'ро': ['р о'],
#              '▁so': ['▁s o', '▁ so'],
#              'so': ['s o'],
#              'ast': ['as t', 'a st'],
#              '()': ['( )'],
#              'swer': ['sw er', 's wer'],
#              'ru': ['r u'],
#              'ies': ['ie s', 'i es'],
#              '▁:': ['▁ :'],
#              'au': ['a u'],
#              'ov': ['o v'],
#              'ре': ['р е'],
#              'го': ['г о'],
#              '▁der': ['▁d er', '▁de r', '▁ der'],
#              '▁my': ['▁m y', '▁ my'],
#              '▁we': ['▁w e', '▁ we'],
#              '▁me': ['▁m e', '▁ me'],
#              'nt': ['n t'],
#              '▁ad': ['▁a d', '▁ ad'],
#              'urn': ['ur n', 'u rn'],
#              '▁your': ['▁y our', '▁you r', '▁yo ur', '▁ your'],
#              '://': [':/ /', ': //'],
#              'are': ['ar e', 'a re'],
#              '▁all': ['▁a ll', '▁al l', '▁ all'],
#              'ff': ['f f'],
#              'io': ['i o'],
#              'estion': ['es tion', 'est ion', 'esti on'],
#              'ime': ['im e', 'i me'],
#              '▁er': ['▁e r', '▁ er'],
#              'lass': ['la ss', 'las s', 'l ass'],
#              '▁и': ['▁ и'],
#              '▁which': ['▁wh ich', '▁ which'],
#              'ome': ['om e', 'o me'],
#              'ont': ['on t', 'o nt'],
#              '▁par': ['▁p ar', '▁pa r', '▁ par'],
#              '▁ma': ['▁m a', '▁ ma'],
#              '▁Y': ['▁ Y'],
#              '",': ['" ,'],
#              '▁о': ['▁ о'],
#              'ft': ['f t'],
#              'ial': ['ia l', 'i al'],
#              'cc': ['c c'],
#              'ound': ['ou nd', 'oun d', 'o und'],
#              '▁li': ['▁l i', '▁ li'],
#              '▁res': ['▁re s', '▁r es', '▁ res'],
#              'eth': ['et h', 'e th'],
#              'ject': ['je ct', 'j ect'],
#              '▁app': ['▁a pp', '▁ap p', '▁ app'],
#              '▁St': ['▁S t', '▁ St'],
#              'ice': ['ic e', 'i ce'],
#              '▁am': ['▁a m', '▁ am'],
#              'act': ['ac t', 'a ct'],
#              '▁del': ['▁d el', '▁de l', '▁ del'],
#              'gr': ['g r'],
#              'ated': ['at ed', 'ate d', 'a ted'],
#              'ier': ['ie r', 'i er'],
#              '▁ab': ['▁a b', '▁ ab'],
#              '▁et': ['▁e t', '▁ et'],
#              'ally': ['al ly', 'all y'],
#              '..': ['. .'],
#              'port': ['po rt', 'por t', 'p ort'],
#              'ik': ['i k'],
#              '▁per': ['▁p er', '▁pe r', '▁ per'],
#              '▁cont': ['▁c ont', '▁con t', '▁co nt', '▁ cont'],
#              'ри': ['р и'],
#              'ка': ['к а'],
#              'ser': ['se r', 's er'],
#              'ли': ['л и'],
#              'll': ['l l'],
#              'iew': ['ie w', 'i ew'],
#              'ign': ['ig n', 'i gn'],
#              '_{': ['_ {'],
#              'put': ['pu t', 'p ut'],
#              'one': ['on e', 'o ne'],
#              'unction': ['un ction', 'unc tion', 'unct ion'],
#              '▁di': ['▁d i', '▁ di'],
#              'ary': ['ar y', 'a ry'],
#              'ition': ['it ion', 'iti on', 'i tion'],
#              'ma': ['m a'],
#              'ен': ['е н'],
#              'get': ['ge t', 'g et'],
#              '▁lo': ['▁l o', '▁ lo'],
#              '▁val': ['▁v al', '▁va l', '▁ val'],
#              '▁Q': ['▁ Q'],
#              'ran': ['ra n', 'r an'],
#              '▁д': ['▁ д'],
#              'ence': ['en ce', 'enc e'],
#              '▁work': ['▁w ork', '▁wor k', '▁ work'],
#              '▁на': ['▁н а', '▁ на'],
#              'ip': ['i p'],
#              'item': ['it em', 'ite m', 'i tem'],
#              'ype': ['yp e', 'y pe'],
#              '▁&': ['▁ &'],
#              '▁his': ['▁h is', '▁hi s', '▁ his'],
#              '▁use': ['▁u se', '▁us e', '▁ use'],
#              'der': ['de r', 'd er'],
#              '▁Answer': ['▁An swer', '▁Ans wer', '▁ Answer'],
#              '▁will': ['▁w ill', '▁wil l', '▁ will'],
#              'ize': ['iz e', 'i ze'],
#              'та': ['т а'],
#              'low': ['lo w', 'l ow'],
#              '▁Ch': ['▁C h', '▁ Ch'],
#              '▁get': ['▁g et', '▁ge t', '▁ get'],
#              'ide': ['id e', 'i de'],
#              'ous': ['ou s', 'o us'],
#              'ink': ['in k'],
#              'ption': ['pt ion', 'p tion'],
#              'ла': ['л а'],
#              'turn': ['tu rn', 't urn'],
#              'ung': ['un g', 'u ng'],
#              'ec': ['e c'],
#              'ug': ['u g'],
#              'form': ['fo rm', 'for m', 'f orm'],
#              'res': ['re s', 'r es'],
#              'htt': ['ht t', 'h tt'],
#              'oug': ['ou g', 'o ug'],
#              'ль': ['л ь'],
#              '▁no': ['▁n o', '▁ no'],
#              'cl': ['c l'],
#              '▁ro': ['▁r o', '▁ ro'],
#              '▁one': ['▁o ne', '▁on e', '▁ one'],
#              'tt': ['t t'],
#              'cri': ['cr i', 'c ri'],
#              'du': ['d u'],
#              '▁up': ['▁u p', '▁ up'],
#              'то': ['т о'],
#              '("': ['( "'],
#              '▁ob': ['▁o b', '▁ ob'],
#              'we': ['w e'],
#              'ory': ['or y', 'o ry'],
#              '▁est': ['▁e st', '▁es t', '▁ est'],
#              'ery': ['er y', 'e ry'],
#              'iel': ['ie l', 'i el'],
#              'str': ['st r', 's tr'],
#              'ob': ['o b'],
#              '▁que': ['▁qu e', '▁q ue', '▁ que'],
#              'ian': ['ia n', 'i an'],
#              '▁out': ['▁o ut', '▁ou t', '▁ out'],
#              '▁pl': ['▁p l', '▁ pl'],
#              '▁new': ['▁n ew', '▁ne w', '▁ new'],
#              'ки': ['к и'],
#              '▁+': ['▁ +'],
#              'ry': ['r y'],
#              'oth': ['ot h', 'o th'],
#              'ther': ['th er', 'the r', 't her'],
#              '▁var': ['▁v ar', '▁va r', '▁ var'],
#              '▁would': ['▁w ould', '▁wo uld'],
#              '▁ser': ['▁s er', '▁se r', '▁ ser'],
#              'tern': ['ter n', 'te rn', 't ern'],
#              'text': ['te xt', 'tex t', 't ext'],
#              '▁there': ['▁t here', '▁th ere', '▁the re', '▁ther e', '▁ there'],
#              'ish': ['is h', 'i sh'],
#              'ror': ['ro r', 'r or'],
#              'те': ['т е'],
#              '▁set': ['▁s et', '▁se t', '▁ set'],
#              '▁@': ['▁ @'],
#              '▁по': ['▁п о', '▁ по'],
#              '▁te': ['▁t e', '▁ te'],
#              'ex': ['e x'],
#              '▁return': ['▁re turn', '▁ret urn', '▁ return'],
#              'ail': ['ai l', 'a il'],
#              '▁any': ['▁a ny', '▁an y', '▁ any'],
#              '▁It': ['▁I t', '▁ It'],
#              '▁function': ['▁f unction',
#               '▁fun ction',
#               '▁func tion',
#               '▁ function'],
#              '{\\': ['{ \\'],
#              "',": ["' ,"],
#              'és': ['é s'],
#              'ale': ['al e', 'a le'],
#              'ан': ['а н'],
#              '▁when': ['▁w hen', '▁wh en', '▁whe n', '▁ when'],
#              'ib': ['i b'],
#              '▁go': ['▁g o', '▁ go'],
#              'ance': ['an ce', 'anc e'],
#              '▁had': ['▁h ad', '▁ha d', '▁ had'],
#              '▁Qu': ['▁Q u', '▁ Qu'],
#              '▁comp': ['▁c omp', '▁com p', '▁co mp', '▁ comp'],
#              'ле': ['л е'],
#              '▁з': ['▁ з'],
#              'math': ['ma th', 'mat h', 'm ath'],
#              '▁has': ['▁h as', '▁ha s', '▁ has'],
#              '▁м': ['▁ м'],
#              '▁pre': ['▁p re', '▁pr e', '▁ pre'],
#              'ener': ['en er', 'ene r', 'e ner'],
#              '▁part': ['▁p art', '▁par t', '▁pa rt', '▁ part'],
#              'elf': ['el f'],
#              '▁die': ['▁d ie', '▁di e', '▁ die'],
#              '▁like': ['▁l ike', '▁li ke', '▁lik e', '▁ like'],
#              'ray': ['ra y', 'r ay'],
#              'irst': ['ir st', 'irs t'],
#              '▁dis': ['▁d is', '▁di s', '▁ dis'],
#              '▁man': ['▁m an', '▁ma n', '▁ man'],
#              'rit': ['ri t', 'r it'],
#              '▁then': ['▁t hen', '▁th en', '▁the n', '▁ then'],
#              '▁class': ['▁c lass', '▁cl ass', '▁cla ss', '▁clas s', '▁ class'],
#              'pro': ['pr o', 'p ro'],
#              '▁po': ['▁p o', '▁ po'],
#              '▁using': ['▁u sing', '▁us ing', '▁ using'],
#              'eb': ['e b'],
#              '▁code': ['▁c ode', '▁co de', '▁cod e', '▁ code'],
#              'own': ['ow n', 'o wn'],
#              '▁some': ['▁s ome', '▁so me', '▁som e', '▁ some'],
#              'ces': ['ce s', 'c es'],
#              '▁$\\': ['▁$ \\', '▁ $\\'],
#              'ер': ['е р'],
#              'lect': ['le ct', 'l ect'],
#              '▁au': ['▁a u', '▁ au'],
#              'isch': ['is ch', 'isc h', 'i sch'],
#              '▁col': ['▁c ol', '▁co l', '▁ col'],
#              '▁–': ['▁ –'],
#              'up': ['u p'],
#              'ons': ['on s', 'o ns'],
#              '▁add': ['▁a dd', '▁ad d', '▁ add'],
#              'ild': ['il d', 'i ld'],
#              'iss': ['is s', 'i ss'],
#              'val': ['va l', 'v al'],
#              'ount': ['ou nt', 'oun t', 'o unt'],
#              'les': ['le s', 'l es'],
#              'vent': ['ve nt', 'ven t', 'v ent'],
#              '▁Z': ['▁ Z'],
#              'In': ['I n'],
#              'row': ['ro w', 'r ow'],
#              'ear': ['ea r', 'e ar'],
#              'ations': ['at ions', 'ation s', 'ati ons', 'atio ns'],
#              'ah': ['a h'],
#              'que': ['qu e', 'q ue'],
#              'ublic': ['ub lic', 'u blic'],
#              'ank': ['an k'],
#              '▁sp': ['▁s p', '▁ sp'],
#              '▁Wh': ['▁W h', '▁ Wh'],
#              '----': ['-- --', '--- -', '- ---'],
#              'sk': ['s k'],
#              'ew': ['e w'],
#              'ags': ['ag s', 'a gs'],
#              'ти': ['т и'],
#              'ann': ['an n', 'a nn'],
#              '▁—': ['▁ —'],
#              'ert': ['er t', 'e rt'],
#              'ace': ['ac e', 'a ce'],
#              'sch': ['sc h', 's ch'],
#              '▁need': ['▁n eed', '▁ne ed', '▁ need'],
#              '▁à': ['▁ à'],
#              'ien': ['ie n', 'i en'],
#              'ough': ['ou gh', 'oug h', 'o ugh'],
#              'не': ['н е'],
#              '▁def': ['▁d ef', '▁de f', '▁ def'],
#              'ij': ['i j'],
#              'ern': ['er n', 'e rn'],
#              '▁what': ['▁w hat', '▁wh at', '▁ what'],
#              '▁Ar': ['▁A r', '▁ Ar'],
#              'wo': ['w o'],
#              'ml': ['m l'],
#              '</': ['< /'],
#              '▁Re': ['▁R e', '▁ Re'],
#              '▁es': ['▁e s', '▁ es'],
#              '▁inst': ['▁in st', '▁ins t', '▁ inst'],
#              'bo': ['b o'],
#              'az': ['a z'],
#              '▁###': ['▁# ##', '▁## #'],
#              '▁б': ['▁ б'],
#              'erm': ['er m', 'e rm'],
#              '▁Al': ['▁A l', '▁ Al'],
#              'led': ['le d', 'l ed'],
#              'да': ['д а'],
#              'ten': ['te n', 't en'],
#              'set': ['se t', 's et'],
#              'ло': ['л о'],
#              '▁comm': ['▁c omm', '▁com m', '▁co mm', '▁ comm'],
#              'sh': ['s h'],
#              'ва': ['в а'],
#              '▁/': ['▁ /'],
#              '▁data': ['▁d ata', '▁da ta', '▁dat a', '▁ data'],
#              '▁//': ['▁/ /', '▁ //'],
#              '](': ['] ('],
#              '▁str': ['▁s tr', '▁st r', '▁ str'],
#              'ose': ['os e', 'o se'],
#              '▁Un': ['▁U n', '▁ Un'],
#              'ven': ['ve n', 'v en'],
#              'St': ['S t'],
#              '...': ['.. .', '. ..'],
#              '▁С': ['▁ С'],
#              'yst': ['ys t', 'y st'],
#              '▁«': ['▁ «'],
#              'ick': ['ic k', 'i ck'],
#              'ix': ['i x'],
#              'par': ['pa r', 'p ar'],
#              '▁у': ['▁ у'],
#              '▁want': ['▁w ant', '▁wa nt'],
#              'ng': ['n g'],
#              'ote': ['ot e', 'o te'],
#              '▁gr': ['▁g r', '▁ gr'],
#              '▁du': ['▁d u', '▁ du'],
#              '▁.': ['▁ .'],
#              'und': ['un d', 'u nd'],
#              '▁only': ['▁on ly', '▁ only'],
#              '▁sa': ['▁s a', '▁ sa'],
#              'ely': ['el y', 'e ly'],
#              'vers': ['ve rs', 'ver s', 'v ers'],
#              '▁ent': ['▁e nt', '▁en t', '▁ ent'],
#              '))': [') )'],
#              "('": ["( '"],
#              '▁mod': ['▁m od', '▁mo d', '▁ mod'],
#              'ava': ['av a', 'a va'],
#              'ton': ['to n', 't on'],
#              '▁should': ['▁sh ould', '▁sho uld', '▁ should'],
#              'ement': ['em ent', 'eme nt', 'emen t', 'e ment'],
#              '▁form': ['▁f orm', '▁for m', '▁fo rm', '▁ form'],
#              '▁also': ['▁al so', '▁als o', '▁ also'],
#              '▁sc': ['▁s c', '▁ sc'],
#              'ings': ['in gs', 'ing s'],
#              '▁You': ['▁Y ou', '▁ You'],
#              'ón': ['ó n'],
#              '▁kn': ['▁k n', '▁ kn'],
#              '();': ['() ;', '( );'],
#              '▁|': ['▁ |'],
#              '▁were': ['▁w ere', '▁we re', '▁wer e'],
#              'ss': ['s s'],
#              '▁Question': ['▁Qu estion', '▁ Question'],
#              'ise': ['is e', 'i se'],
#              '▁they': ['▁th ey', '▁the y', '▁ they'],
#              '▁De': ['▁D e', '▁ De'],
#              'ond': ['on d', 'o nd'],
#              '▁sol': ['▁s ol', '▁so l', '▁ sol'],
#              '▁fol': ['▁f ol', '▁fo l', '▁ fol'],
#              '▁more': ['▁m ore', '▁mo re', '▁mor e', '▁ more'],
#              '▁her': ['▁h er', '▁he r', '▁ her'],
#              '▁_': ['▁ _'],
#              '▁é': ['▁ é'],
#              'atch': ['at ch'],
#              'fter': ['ft er', 'fte r', 'f ter'],
#              '▁cre': ['▁c re', '▁cr e', '▁ cre'],
#              'lock': ['lo ck', 'loc k', 'l ock'],
#              'tring': ['tr ing', 'tri ng', 't ring'],
#              '▁This': ['▁T his', '▁Th is', '▁ This'],
#              'ze': ['z e'],
#              'ado': ['ad o', 'a do'],
#              'ull': ['ul l', 'u ll'],
#              'ger': ['ge r', 'g er'],
#              'be': ['b e'],
#              '▁other': ['▁o ther', '▁ot her', '▁ other'],
#              '▁Tags': ['▁T ags', '▁Tag s', '▁Ta gs', '▁ Tags'],
#              'ution': ['ut ion', 'uti on', 'u tion'],
#              'ict': ['ic t', 'i ct'],
#              '▁how': ['▁h ow', '▁ho w', '▁ how'],
#              '▁x': ['▁ x'],
#              '▁Se': ['▁S e', '▁ Se'],
#              '▁che': ['▁c he', '▁ch e', '▁ che'],
#              'cript': ['cri pt', 'cr ipt'],
#              '▁just': ['▁j ust', '▁ju st', '▁ just'],
#              '▁pos': ['▁p os', '▁po s', '▁ pos'],
#              'ange': ['an ge', 'ang e'],
#              'ific': ['if ic', 'ifi c', 'i fic'],
#              'ree': ['re e', 'r ee'],
#              '}}': ['} }'],
#              '▁time': ['▁t ime', '▁tim e', '▁ti me', '▁ time'],
#              'app': ['ap p', 'a pp'],
#              'ны': ['н ы'],
#              '▁file': ['▁f ile', '▁fil e', '▁fi le', '▁ file'],
#              'ark': ['ar k'],
#              'ical': ['ic al', 'ica l', 'i cal'],
#              '▁first': ['▁f irst', '▁fir st', '▁ first'],
#              '▁int': ['▁in t', '▁i nt', '▁ int'],
#              '▁В': ['▁ В'],
#              '▁He': ['▁H e', '▁ He'],
#              'ta': ['t a'],
#              'ument': ['um ent', 'ume nt', 'umen t', 'u ment'],
#              'ors': ['or s', 'o rs'],
#              'lement': ['le ment', 'lem ent', 'l ement'],
#              'rac': ['ra c', 'r ac'],
#              '▁ag': ['▁a g', '▁ ag'],
#              '▁does': ['▁do es', '▁ does'],
#              'yn': ['y n'],
#              'read': ['re ad', 'rea d', 'r ead'],
#              'ual': ['ua l', 'u al'],
#              '▁Le': ['▁L e', '▁ Le'],
#              'ys': ['y s'],
#              '▁em': ['▁e m', '▁ em'],
#              '▁num': ['▁n um', '▁nu m', '▁ num'],
#              'vel': ['ve l', 'v el'],
#              'ди': ['д и'],
#              'over': ['ov er', 'ove r', 'o ver'],
#              '▁dif': ['▁d if', '▁di f'],
#              'ethod': ['et hod', 'eth od'],
#              '▁If': ['▁I f', '▁ If'],
#              '▁spe': ['▁s pe', '▁sp e', '▁ spe'],
#              'ym': ['y m'],
#              '▁them': ['▁t hem', '▁th em', '▁the m'],
#              '▁into': ['▁in to', '▁int o', '▁ into'],
#              '▁les': ['▁l es', '▁le s', '▁ les'],
#              '▁its': ['▁it s', '▁i ts', '▁ its'],
#              'ese': ['es e', 'e se'],
#              'ield': ['ie ld', 'iel d', 'i eld'],
#              '▁public': ['▁p ublic',
#               '▁pub lic',
#               '▁pu blic',
#               '▁publi c',
#               '▁ public'],
#              '▁П': ['▁ П'],
#              '▁den': ['▁d en', '▁de n', '▁ den'],
#              'ystem': ['yst em', 'ys tem'],
#              'of': ['o f'],
#              '▁over': ['▁o ver', '▁ov er', '▁ over'],
#              '->': ['- >'],
#              '▁fil': ['▁f il', '▁fi l', '▁ fil'],
#              'name': ['na me', 'nam e', 'n ame'],
#              'inal': ['in al', 'ina l', 'i nal'],
#              '▁il': ['▁i l', '▁ il'],
#              'ample': ['am ple', 'amp le'],
#              '▁way': ['▁w ay', '▁wa y', '▁ way'],
#              'ica': ['ic a', 'i ca'],
#              'во': ['в о'],
#              'cess': ['ce ss', 'ces s', 'c ess'],
#              'itt': ['it t', 'i tt'],
#              'uch': ['uc h', 'u ch'],
#              '▁where': ['▁w here', '▁wh ere', '▁whe re', '▁ where'],
#              'ми': ['м и'],
#              'org': ['or g', 'o rg'],
#              'https': ['htt ps', 'http s'],
#              '▁vo': ['▁v o', '▁ vo'],
#              'ient': ['ie nt', 'ien t', 'i ent'],
#              'ove': ['ov e', 'o ve'],
#              '▁value': ['▁val ue', '▁valu e', '▁ value'],
#              'eng': ['en g', 'e ng'],
#              '▁La': ['▁L a', '▁ La'],
#              '^{': ['^ {'],
#              'ref': ['re f', 'r ef'],
#              'ied': ['ie d', 'i ed'],
#              'ER': ['E R'],
#              '▁stat': ['▁s tat', '▁st at', '▁sta t', '▁ stat'],
#              'fig': ['fi g', 'f ig'],
#              'me': ['m e'],
#              '▁von': ['▁v on', '▁vo n', '▁ von'],
#              '▁inter': ['▁in ter', '▁int er', '▁inte r', '▁ inter'],
#              'roid': ['ro id', 'r oid'],
#              'ater': ['at er', 'ate r', 'a ter'],
#              '▁their': ['▁the ir'],
#              '▁bet': ['▁b et', '▁be t', '▁ bet'],
#              '▁ein': ['▁e in', '▁ ein'],
#              '}\\': ['} \\'],
#              '">': ['" >'],
#              '▁sub': ['▁s ub', '▁su b', '▁ sub'],
#              '▁op': ['▁o p', '▁ op'],
#              '▁don': ['▁d on', '▁do n', '▁ don'],
#              'ty': ['t y'],
#              '▁try': ['▁t ry', '▁tr y', '▁ try'],
#              '▁Pro': ['▁P ro', '▁Pr o', '▁ Pro'],
#              '▁tra': ['▁t ra', '▁tr a', '▁ tra'],
#              '▁same': ['▁s ame', '▁sa me', '▁sam e', '▁ same'],
#              'ep': ['e p'],
#              '▁two': ['▁t wo', '▁tw o', '▁ two'],
#              '▁name': ['▁n ame', '▁na me', '▁nam e', '▁ name'],
#              'old': ['ol d', 'o ld'],
#              'let': ['le t', 'l et'],
#              '▁sim': ['▁s im', '▁si m', '▁ sim'],
#              'sp': ['s p'],
#              '▁av': ['▁a v', '▁ av'],
#              'bre': ['br e', 'b re'],
#              'blem': ['ble m', 'bl em', 'b lem'],
#              'ey': ['e y'],
#              '▁could': ['▁c ould', '▁co uld', '▁cou ld', '▁ could'],
#              '▁cor': ['▁c or', '▁co r', '▁ cor'],
#              '▁acc': ['▁a cc', '▁ac c', '▁ acc'],
#              'ays': ['ay s', 'a ys'],
#              'cre': ['cr e', 'c re'],
#              'urr': ['ur r', 'u rr'],
#              'si': ['s i'],
#              '▁const': ['▁con st', '▁cons t', '▁ const'],
#              'ues': ['ue s', 'u es'],
#              '}$': ['} $'],
#              'View': ['V iew'],
#              '▁act': ['▁a ct', '▁ac t', '▁ act'],
#              '▁bo': ['▁b o', '▁ bo'],
#              '▁ко': ['▁к о', '▁ ко'],
#              '▁som': ['▁s om', '▁so m', '▁ som'],
#              '▁about': ['▁ab out', '▁ about'],
#              'land': ['la nd', 'lan d', 'l and'],
#              'mer': ['me r', 'm er'],
#              '▁list': ['▁l ist', '▁li st', '▁ list'],
#              'cal': ['ca l', 'c al'],
#              '▁import': ['▁im port', '▁imp ort', '▁ import'],
#              'col': ['co l', 'c ol'],
#              '▁na': ['▁n a', '▁ na'],
#              'na': ['n a'],
#              '::': [': :'],
#              '▁who': ['▁w ho', '▁wh o', '▁ who'],
#              '▁error': ['▁e rror', '▁er ror', '▁err or', '▁ error'],
#              '▁X': ['▁ X'],
#              'ator': ['at or', 'ato r', 'a tor'],
#              'ext': ['ex t', 'e xt'],
#              '▁been': ['▁b een', '▁be en'],
#              'ér': ['é r'],
#              '▁run': ['▁r un', '▁ru n', '▁ run'],
#              'pos': ['po s', 'p os'],
#              '▁cl': ['▁c l', '▁ cl'],
#              '**': ['* *'],
#              '▁К': ['▁ К'],
#              'ular': ['ul ar', 'ula r', 'u lar'],
#              'ause': ['au se', 'aus e', 'a use'],
#              '▁reg': ['▁re g', '▁r eg', '▁ reg'],
#              '▁know': ['▁k now', '▁kn ow', '▁ know'],
#              '▁see': ['▁s ee', '▁se e', '▁ see'],
#              '▁him': ['▁h im', '▁hi m', '▁ him'],
#              'ning': ['ni ng', 'n ing'],
#              '▁за': ['▁з а', '▁ за'],
#              'ates': ['at es', 'ate s', 'a tes'],
#              'fore': ['fo re', 'for e', 'f ore'],
#              'ions': ['ion s', 'io ns', 'i ons'],
#              '▁hel': ['▁h el', '▁he l', '▁ hel'],
#              'ute': ['ut e', 'u te'],
#              '▁rem': ['▁re m', '▁r em', '▁ rem'],
#              '▁го': ['▁г о', '▁ го'],
#              '▁Mar': ['▁M ar', '▁Ma r', '▁ Mar'],
#              'ру': ['р у'],
#              'vice': ['vi ce', 'vic e', 'v ice'],
#              'irect': ['ir ect', 'ire ct', 'i rect'],
#              'ner': ['ne r', 'n er'],
#              '▁under': ['▁u nder', '▁un der', '▁und er', '▁ under'],
#              'rib': ['ri b', 'r ib'],
#              'hr': ['h r'],
#              'че': ['ч е'],
#              '▁As': ['▁A s', '▁ As'],
#              '▁end': ['▁e nd', '▁en d', '▁ end'],
#              'ember': ['em ber', 'emb er'],
#              '▁а': ['▁ а'],
#              '▁att': ['▁a tt', '▁at t', '▁ att'],
#              'ina': ['in a', 'i na'],
#              'son': ['so n', 's on'],
#              '▁follow': ['▁f ollow', '▁fol low', '▁ follow'],
#              '▁Sch': ['▁S ch', '▁Sc h', '▁ Sch'],
#              'pect': ['pe ct', 'pec t', 'p ect'],
#              '▁rel': ['▁re l', '▁r el', '▁ rel'],
#              '▁So': ['▁S o', '▁ So'],
#              '▁look': ['▁l ook', '▁lo ok', '▁ look'],
#              'abel': ['ab el', 'abe l', 'a bel'],
#              '▁problem': ['▁pro blem',
#               '▁prob lem',
#               '▁proble m',
#               '▁probl em',
#               '▁ problem'],
#              '▁van': ['▁v an', '▁va n', '▁ van'],
#              'strong': ['st rong', 'str ong'],
#              'co': ['c o'],
#              'pon': ['po n', 'p on'],
#              'ca': ['c a'],
#              'ada': ['ad a', 'a da'],
#              '":': ['" :'],
#              'cond': ['con d', 'co nd', 'c ond'],
#              'amb': ['am b', 'a mb'],
#              '},': ['} ,'],
#              'quest': ['qu est', 'que st', 'ques t', 'q uest'],
#              '▁aut': ['▁a ut', '▁au t', '▁ aut'],
#              '▁result': ['▁res ult', '▁ result'],
#              '▁may': ['▁m ay', '▁ma y', '▁ may'],
#              'Re': ['R e'],
#              'http': ['ht tp', 'htt p', 'h ttp'],
#              '):': [') :'],
#              '▁And': ['▁A nd', '▁An d', '▁ And'],
#              'red': ['re d', 'r ed'],
#              '▁How': ['▁H ow', '▁Ho w', '▁ How'],
#              'po': ['p o'],
#              'ско': ['ск о', 'с ко'],
#              'att': ['at t', 'a tt'],
#              'oup': ['ou p', 'o up'],
#              'ced': ['ce d', 'c ed'],
#              '▁type': ['▁t ype', '▁typ e', '▁ty pe', '▁ type'],
#              '▁than': ['▁t han', '▁th an', '▁ than'],
#              '▁cons': ['▁c ons', '▁con s', '▁co ns', '▁ cons'],
#              'uf': ['u f'],
#              'ци': ['ц и'],
#              '▁question': ['▁qu estion',
#               '▁quest ion',
#               '▁questi on',
#               '▁ question'],
#              'raph': ['ra ph', 'rap h', 'r aph'],
#              'igh': ['ig h', 'i gh'],
#              '▁М': ['▁ М'],
#              '▁htt': ['▁h tt', '▁ htt'],
#              'ins': ['in s', 'i ns'],
#              'den': ['de n', 'd en'],
#              '▁da': ['▁d a', '▁ da'],
#              '▁ver': ['▁v er', '▁ve r', '▁ ver'],
#              'oh': ['o h'],
#              '▁=>': ['▁= >', '▁ =>'],
#              'riv': ['ri v', 'r iv'],
#              'ude': ['ud e', 'u de'],
#              '▁For': ['▁F or', '▁Fo r', '▁ For'],
#              '▁ra': ['▁r a', '▁ ra'],
#              'frac': ['fr ac', 'fra c', 'f rac'],
#              'ма': ['м а'],
#              '▁after': ['▁a fter', '▁af ter', '▁ after'],
#              '}{': ['} {'],
#              '▁method': ['▁m ethod', '▁met hod', '▁ method'],
#              '")': ['" )'],
#              'amp': ['am p', 'a mp'],
#              'ash': ['as h', 'a sh'],
#              '▁rec': ['▁re c', '▁r ec', '▁ rec'],
#              '▁differ': ['▁d iffer', '▁dif fer', '▁diff er'],
#              'ON': ['O N'],
#              'ax': ['a x'],
#              'ament': ['am ent', 'ame nt', 'amen t', 'a ment'],
#              'ource': ['our ce'],
#              'Con': ['Co n', 'C on'],
#              'its': ['it s', 'i ts'],
#              'Name': ['Na me', 'N ame'],
#              'man': ['ma n', 'm an'],
#              '▁bec': ['▁b ec', '▁be c', '▁ bec'],
#              'che': ['ch e', 'c he'],
#              '▁En': ['▁E n', '▁ En'],
#              'aj': ['a j'],
#              '▁gener': ['▁g ener', '▁ge ner', '▁gen er', '▁gene r', '▁ gener'],
#              'IN': ['I N'],
#              '▁id': ['▁i d', '▁ id'],
#              'ages': ['ag es', 'age s', 'a ges'],
#              '▁loc': ['▁l oc', '▁lo c', '▁ loc'],
#              'fo': ['f o'],
#              'br': ['b r'],
#              '▁she': ['▁s he', '▁sh e', '▁ she'],
#              'Pro': ['Pr o', 'P ro'],
#              '▁una': ['▁u na', '▁un a', '▁ una'],
#              '▁к': ['▁ к'],
#              'eta': ['et a', 'e ta'],
#              'log': ['lo g', 'l og'],
#              'olog': ['ol og', 'olo g', 'o log'],
#              '▁sur': ['▁s ur', '▁su r', '▁ sur'],
#              'arg': ['ar g', 'a rg'],
#              '▁--': ['▁- -', '▁ --'],
#              'kt': ['k t'],
#              '(\\': ['( \\'],
#              'min': ['mi n', 'm in'],
#              '▁line': ['▁l ine', '▁li ne', '▁lin e', '▁ line'],
#              '▁vari': ['▁v ari', '▁var i', '▁va ri', '▁ vari'],
#              'ся': ['с я'],
#              'ics': ['ic s', 'i cs'],
#              'ня': ['н я'],
#              'very': ['ve ry', 'ver y', 'v ery'],
#              'add': ['ad d', 'a dd'],
#              '▁object': ['▁o bject', '▁ob ject', '▁obj ect', '▁ object'],
#              'Id': ['I d'],
#              '▁But': ['▁B ut', '▁Bu t', '▁ But'],
#              '▁case': ['▁c ase', '▁cas e', '▁ca se', '▁ case'],
#              '▁make': ['▁m ake', '▁ma ke', '▁mak e', '▁ make'],
#              '▁cal': ['▁c al', '▁ca l', '▁ cal'],
#              '▁pass': ['▁p ass', '▁pas s', '▁pa ss', '▁ pass'],
#              'сь': ['с ь'],
#              'ession': ['ess ion'],
#              'net': ['ne t', 'n et'],
#              '."': ['. "'],
#              '▁г': ['▁ г'],
#              'är': ['ä r'],
#              'де': ['д е'],
#              'no': ['n o'],
#              'ating': ['at ing', 'ati ng', 'atin g', 'a ting'],
#              'ato': ['at o', 'a to'],
#              'line': ['li ne', 'lin e', 'l ine'],
#              'ви': ['в и'],
#              '▁Ex': ['▁E x', '▁ Ex'],
#              '▁ass': ['▁a ss', '▁as s', '▁ ass'],
#              '▁vers': ['▁v ers', '▁ver s', '▁ve rs', '▁ vers'],
#              'ля': ['л я'],
#              '▁ed': ['▁e d', '▁ ed'],
#              'umn': ['um n', 'u mn'],
#              'other': ['ot her', 'oth er', 'othe r', 'o ther'],
#              'ста': ['ст а', 'с та'],
#              'ative': ['at ive', 'ativ e', 'ati ve'],
#              'String': ['St ring', 'Str ing', 'S tring'],
#              '▁los': ['▁l os', '▁lo s', '▁ los'],
#              'wn': ['w n'],
#              '▁answer': ['▁an swer', '▁ans wer', '▁ answer'],
#              '▁let': ['▁l et', '▁le t', '▁ let'],
#              '▁pe': ['▁p e', '▁ pe'],
#              'ents': ['en ts', 'ent s'],
#              '▁fe': ['▁f e', '▁ fe'],
#              'ince': ['in ce', 'inc e'],
#              'ni': ['n i'],
#              'ider': ['id er', 'ide r', 'i der'],
#              'ows': ['ow s', 'o ws'],
#              '▁test': ['▁t est', '▁te st', '▁ test'],
#              '▁here': ['▁h ere', '▁he re', '▁her e', '▁ here'],
#              'roll': ['ro ll', 'rol l', 'r oll'],
#              '▁call': ['▁c all', '▁cal l', '▁ca ll', '▁ call'],
#              'ruct': ['ru ct', 'r uct'],
#              '▁pol': ['▁p ol', '▁po l', '▁ pol'],
#              'ait': ['ai t', 'a it'],
#              '▁back': ['▁b ack', '▁ba ck', '▁ back'],
#              'ho': ['h o'],
#              'Ex': ['E x'],
#              'ress': ['re ss', 'res s', 'r ess'],
#              'ST': ['S T'],
#              'ried': ['ri ed', 'rie d', 'r ied'],
#              'date': ['da te', 'dat e', 'd ate'],
#              'ет': ['е т'],
#              '▁did': ['▁d id', '▁di d', '▁ did'],
#              'ting': ['ti ng', 't ing'],
#              '▁El': ['▁E l', '▁ El'],
#              '▁dem': ['▁d em', '▁de m', '▁ dem'],
#              ')$': [') $'],
#              'ова': ['ов а', 'о ва'],
#              'urrent': ['ur rent', 'urr ent', 'urre nt'],
#              'lace': ['la ce', 'lac e', 'l ace'],
#              'right': ['rig ht', 'r ight'],
#              'ren': ['re n', 'r en'],
#              ...})

# %%
def get_merge_ranks(token, token_to_used_merge):
    """
    Given a token and the dictionary token_to_used_merge which contains the last merge for forming each token,
    return a list containing all merge ranks used in the formation of token.
    """
    if token not in token_to_rank:
        return [-1]
    if token not in token_to_used_merge:  # this token hasn't even been formed by prior merge rules yet!
        return [float('inf')]
    l, r = token_to_used_merge[token].split(' ')
    ranks = get_merge_ranks(l, token_to_used_merge) + get_merge_ranks(r, token_to_used_merge)
    ranks.append(token_to_rank[token])
    return ranks

# %%
def clean_up_symmetric_merges(rank):
    """
    Break ties by putting the longer token on the left.
    """
    token_pairs = []
    to_remove = []
    for m in rank:
        l, r = m.split(' ')
        unordered_pair = set([l, r])
        if unordered_pair in token_pairs:
            if len(l) > len(r):
                to_remove.append(f'{r} {l}')
            elif len(l) < len(r):
                to_remove.append(f'{l} {r}')
        token_pairs.append(set([l, r]))
    for m in to_remove:
        rank.pop(m)
    return rank

# %%
token_to_used_merge = {}
for token, group in token_to_merges.items():
    if len(group) == 1:
        token_to_used_merge[token] = group[0]
    else:
        rank = {}
        for m in group:
            l, r = m.split(' ')
            rank[m] = get_merge_ranks(l, token_to_used_merge) + get_merge_ranks(r, token_to_used_merge)
        rank = clean_up_symmetric_merges(rank)
        rank = {k: sorted([m for m in v if m != -1]) for k, v in rank.items()}
        token_to_used_merge[token] = min(rank, key=rank.get)

# %%
cleaned_merges = []
for token in sorted(token_to_rank, key=token_to_rank.get):
    if token in token_to_used_merge:
        used_merge = token_to_used_merge[token]
        if model_name in ['llama', 'gemma', 'mixtral']:
            used_merge = used_merge.replace('\r', '\\r')
        cleaned_merges.append(used_merge)

# %%
cleaned_merges
# Out:
# ['▁ t',
#  'e r',
#  'i n',
#  '▁ a',
#  'e n',
#  'o n',
#  '▁t h',
#  'e s',
#  '▁ s',
#  '▁ d',
#  'a t',
#  'o r',
#  'a n',
#  '▁ c',
#  'i s',
#  'r e',
#  'i t',
#  '▁th e',
#  'a r',
#  'l e',
#  '▁ w',
#  '▁ p',
#  'o u',
#  'a l',
#  '▁ f',
#  '▁ m',
#  'e d',
#  '▁ o',
#  '▁ b',
#  'o m',
#  'i on',
#  'in g',
#  'i c',
#  'a s',
#  'e l',
#  'en t',
#  '▁ in',
#  '▁ h',
#  'n d',
#  'e t',
#  '▁ l',
#  '▁ n',
#  's t',
#  '▁t o',
#  'c h',
#  '▁ I',
#  'r o',
#  'i l',
#  '▁o f',
#  'd e',
#  'c t',
#  '▁ (',
#  'a m',
#  '▁ C',
#  '▁d e',
#  '▁ S',
#  '▁ u',
#  '▁ A',
#  '▁ \\',
#  '▁ e',
#  '▁a nd',
#  '▁ T',
#  'o l',
#  '▁ v',
#  'i m',
#  'o t',
#  'a d',
#  'u t',
#  '▁ g',
#  'e m',
#  'u r',
#  'i d',
#  '▁ *',
#  'i g',
#  'r a',
#  '▁ re',
#  '▁ is',
#  'q u',
#  'o w',
#  '▁ M',
#  'es t',
#  '▁ y',
#  's e',
#  'v e',
#  'c e',
#  'i e',
#  'u n',
#  '▁ P',
#  '▁ B',
#  'a g',
#  'u l',
#  '▁ =',
#  'h e',
#  'en d',
#  'o de',
#  't er',
#  'm ent',
#  'o s',
#  '▁ D',
#  'i f',
#  'at ion',
#  '▁f or',
#  '▁ r',
#  '▁ L',
#  '▁y ou',
#  '▁b e',
#  'l y',
#  'v er',
#  'a b',
#  't e',
#  '▁ it',
#  '▁ on',
#  'r i',
#  'u s',
#  '▁ "',
#  '▁w h',
#  '▁c on',
#  '▁ H',
#  '▁s t',
#  'i r',
#  '▁ E',
#  '▁ F',
#  'c k',
#  '▁a n',
#  't h',
#  'e g',
#  'a y',
#  'it h',
#  '▁ R',
#  'is t',
#  'an d',
#  '▁th at',
#  '▁a l',
#  '▁ $',
#  '▁ #',
#  'o d',
#  'u m',
#  '▁ W',
#  'h t',
#  'c ode',
#  '▁ G',
#  'at e',
#  'es s',
#  '▁ N',
#  'er e',
#  'p p',
#  '▁a s',
#  '▁s e',
#  '▁p ro',
#  '▁w ith',
#  'p e',
#  '▁ k',
#  'er s',
#  'p t',
#  ') ;',
#  'l o',
#  '▁c om',
#  'am e',
#  '▁ `',
#  '▁C om',
#  'i a',
#  'an t',
#  '▁l a',
#  '▁ {',
#  '▁ en',
#  'ct ion',
#  '▁e x',
#  'l d',
#  'u b',
#  '▁ j',
#  'l a',
#  'u e',
#  '▁ J',
#  'ic h',
#  '▁d o',
#  '▁ O',
#  '▁ qu',
#  'i v',
#  'or t',
#  'ar t',
#  '▁u n',
#  '▁# #',
#  '▁th is',
#  'k e',
#  '▁h a',
#  '▁ -',
#  'ou t',
#  '▁T he',
#  '▁n ot',
#  '▁n e',
#  'il l',
#  '▁ le',
#  'c i',
#  'r om',
#  'in e',
#  '/ /',
#  'o p',
#  'eg in',
#  '▁Com ment',
#  'b egin',
#  'с т',
#  'as s',
#  'i z',
#  ') .',
#  'o g',
#  '▁ п',
#  '▁ or',
#  '▁w as',
#  '▁a t',
#  'ou r',
#  '▁ i',
#  'a in',
#  '▁ K',
#  'н а',
#  '▁ V',
#  'g e',
#  '▁s u',
#  'a p',
#  'ag e',
#  'ou ld',
#  'n e',
#  'a v',
#  'x t',
#  'or e',
#  'i le',
#  '- -',
#  '▁ в',
#  '▁b y',
#  'l i',
#  'at h',
#  'р а',
#  'b er',
#  'a ch',
#  'al l',
#  '▁T h',
#  'ul t',
#  '▁ }',
#  '▁ U',
#  '▁u s',
#  '▁ z',
#  'u st',
#  '▁ha ve',
#  'l ic',
#  'н и',
#  '▁c an',
#  't r',
#  'c om',
#  ') ,',
#  '▁I n',
#  'in d',
#  'el l',
#  '▁f rom',
#  'о в',
#  't o',
#  '▁ [',
#  'ab le',
#  'o st',
#  '▁c h',
#  'e ct',
#  'ig ht',
#  'in t',
#  "▁ '",
#  '▁a re',
#  '▁ im',
#  '▁s h',
#  '▁ <',
#  '▁A n',
#  '▁ с',
#  'at a',
#  'i re',
#  '▁t r',
#  'c on',
#  'or d',
#  'it y',
#  'ar d',
#  '▁h e',
#  '▁b ut',
#  'o c',
#  '= "',
#  '▁p r',
#  'u re',
#  'p er',
#  'a ck',
#  'or k',
#  'on g',
#  'an s',
#  'к о',
#  'p le',
#  '▁d es',
#  'o k',
#  'or m',
#  'w er',
#  'a k',
#  'p r',
#  'as e',
#  '▁ el',
#  'p h',
#  'a c',
#  '▁u nd',
#  '▁a r',
#  '▁ if',
#  'u d',
#  'p s',
#  'it e',
#  'b le',
#  'н о',
#  'f er',
#  'p l',
#  'i ve',
#  'an g',
#  'en s',
#  'р о',
#  '▁s o',
#  's o',
#  'as t',
#  '( )',
#  's wer',
#  'r u',
#  'i es',
#  '▁ :',
#  'a u',
#  'o v',
#  'р е',
#  'г о',
#  '▁d er',
#  '▁m y',
#  '▁w e',
#  '▁m e',
#  'n t',
#  '▁a d',
#  'ur n',
#  '▁you r',
#  ': //',
#  'a re',
#  '▁al l',
#  'f f',
#  'i o',
#  'est ion',
#  'im e',
#  '▁ er',
#  'l ass',
#  '▁ и',
#  '▁wh ich',
#  'om e',
#  'on t',
#  '▁p ar',
#  '▁m a',
#  '▁ Y',
#  '" ,',
#  '▁ о',
#  'f t',
#  'i al',
#  'c c',
#  'ou nd',
#  '▁l i',
#  '▁r es',
#  'et h',
#  'j ect',
#  '▁a pp',
#  '▁S t',
#  'ic e',
#  '▁a m',
#  'a ct',
#  '▁d el',
#  'g r',
#  'at ed',
#  'i er',
#  '▁a b',
#  '▁ et',
#  'al ly',
#  '. .',
#  'p ort',
#  'i k',
#  '▁p er',
#  '▁con t',
#  'р и',
#  'к а',
#  's er',
#  'л и',
#  'l l',
#  'ie w',
#  'ig n',
#  '_ {',
#  'p ut',
#  'on e',
#  'un ction',
#  '▁d i',
#  'ar y',
#  'it ion',
#  'm a',
#  'е н',
#  'g et',
#  '▁l o',
#  '▁v al',
#  '▁ Q',
#  'r an',
#  '▁ д',
#  'en ce',
#  '▁w ork',
#  '▁ на',
#  'i p',
#  'it em',
#  'y pe',
#  '▁ &',
#  '▁h is',
#  '▁u se',
#  'd er',
#  '▁An swer',
#  '▁w ill',
#  'iz e',
#  'т а',
#  'l ow',
#  '▁C h',
#  '▁g et',
#  'i de',
#  'ou s',
#  'in k',
#  'pt ion',
#  'л а',
#  't urn',
#  'un g',
#  'e c',
#  'u g',
#  'f orm',
#  'r es',
#  'ht t',
#  'ou g',
#  'л ь',
#  '▁n o',
#  'c l',
#  '▁ ro',
#  '▁on e',
#  't t',
#  'c ri',
#  'd u',
#  '▁u p',
#  'т о',
#  '( "',
#  '▁o b',
#  'w e',
#  'or y',
#  '▁ est',
#  'er y',
#  'i el',
#  'st r',
#  'o b',
#  '▁qu e',
#  'i an',
#  '▁ out',
#  '▁p l',
#  '▁ne w',
#  'к и',
#  '▁ +',
#  'r y',
#  'ot h',
#  'th er',
#  '▁v ar',
#  '▁w ould',
#  '▁s er',
#  'ter n',
#  'te xt',
#  '▁th ere',
#  'is h',
#  'r or',
#  'т е',
#  '▁s et',
#  '▁ @',
#  '▁п о',
#  '▁t e',
#  'e x',
#  '▁re turn',
#  'a il',
#  '▁an y',
#  '▁I t',
#  '▁f unction',
#  '{ \\',
#  "' ,",
#  'é s',
#  'a le',
#  'а н',
#  '▁wh en',
#  'i b',
#  '▁g o',
#  'an ce',
#  '▁h ad',
#  '▁Q u',
#  '▁com p',
#  'л е',
#  '▁ з',
#  'm ath',
#  '▁h as',
#  '▁ м',
#  '▁p re',
#  'en er',
#  '▁p art',
#  'el f',
#  '▁d ie',
#  '▁li ke',
#  'ra y',
#  'ir st',
#  '▁d is',
#  '▁m an',
#  'r it',
#  '▁th en',
#  '▁c lass',
#  'p ro',
#  '▁p o',
#  '▁us ing',
#  'e b',
#  '▁c ode',
#  'ow n',
#  '▁s ome',
#  'c es',
#  '▁$ \\',
#  'е р',
#  'le ct',
#  '▁a u',
#  'is ch',
#  '▁c ol',
#  '▁ –',
#  'u p',
#  'on s',
#  '▁ad d',
#  'il d',
#  'is s',
#  'v al',
#  'ou nt',
#  'l es',
#  'v ent',
#  '▁ Z',
#  'I n',
#  'ro w',
#  'e ar',
#  'ation s',
#  'a h',
#  'qu e',
#  'ub lic',
#  'an k',
#  '▁s p',
#  '▁W h',
#  '-- --',
#  's k',
#  'e w',
#  'ag s',
#  'т и',
#  'an n',
#  '▁ —',
#  'er t',
#  'a ce',
#  's ch',
#  '▁ne ed',
#  '▁ à',
#  'i en',
#  'oug h',
#  'н е',
#  '▁de f',
#  'i j',
#  'er n',
#  '▁wh at',
#  '▁A r',
#  'w o',
#  'm l',
#  '< /',
#  '▁R e',
#  '▁ es',
#  '▁in st',
#  'b o',
#  'a z',
#  '▁## #',
#  '▁ б',
#  'er m',
#  '▁A l',
#  'le d',
#  'д а',
#  't en',
#  's et',
#  'л о',
#  '▁com m',
#  's h',
#  'в а',
#  '▁ /',
#  '▁d ata',
#  '▁ //',
#  '] (',
#  '▁st r',
#  'o se',
#  '▁U n',
#  'v en',
#  'S t',
#  '.. .',
#  '▁ С',
#  'y st',
#  '▁ «',
#  'ic k',
#  'i x',
#  'p ar',
#  '▁ у',
#  '▁w ant',
#  'n g',
#  'ot e',
#  '▁g r',
#  '▁d u',
#  '▁ .',
#  'u nd',
#  '▁on ly',
#  '▁s a',
#  'el y',
#  'ver s',
#  '▁ ent',
#  ') )',
#  "( '",
#  '▁m od',
#  'av a',
#  't on',
#  '▁sh ould',
#  'em ent',
#  '▁for m',
#  '▁al so',
#  '▁s c',
#  'ing s',
#  '▁Y ou',
#  'ó n',
#  '▁k n',
#  '( );',
#  '▁ |',
#  '▁w ere',
#  's s',
#  '▁Qu estion',
#  'is e',
#  '▁the y',
#  '▁D e',
#  'on d',
#  '▁s ol',
#  '▁f ol',
#  '▁m ore',
#  '▁h er',
#  '▁ _',
#  '▁ é',
#  'at ch',
#  'f ter',
#  '▁c re',
#  'lo ck',
#  'tr ing',
#  '▁Th is',
#  'z e',
#  'ad o',
#  'ul l',
#  'g er',
#  'b e',
#  '▁o ther',
#  '▁T ags',
#  'ut ion',
#  'ic t',
#  '▁h ow',
#  '▁ x',
#  '▁S e',
#  '▁c he',
#  'cri pt',
#  '▁j ust',
#  '▁p os',
#  'an ge',
#  'if ic',
#  're e',
#  '} }',
#  '▁t ime',
#  'a pp',
#  'н ы',
#  '▁f ile',
#  'ar k',
#  'ic al',
#  '▁f irst',
#  '▁in t',
#  '▁ В',
#  '▁H e',
#  't a',
#  'u ment',
#  'or s',
#  'le ment',
#  'ra c',
#  '▁a g',
#  '▁do es',
#  'y n',
#  're ad',
#  'u al',
#  '▁L e',
#  'y s',
#  '▁e m',
#  '▁n um',
#  'v el',
#  'д и',
#  'o ver',
#  '▁d if',
#  'eth od',
#  '▁I f',
#  '▁s pe',
#  'y m',
#  '▁the m',
#  '▁in to',
#  '▁l es',
#  '▁it s',
#  'es e',
#  'iel d',
#  '▁p ublic',
#  '▁ П',
#  '▁d en',
#  'yst em',
#  'o f',
#  '▁o ver',
#  '- >',
#  '▁f il',
#  'n ame',
#  'in al',
#  '▁ il',
#  'am ple',
#  '▁w ay',
#  'ic a',
#  'в о',
#  'c ess',
#  'it t',
#  'u ch',
#  '▁wh ere',
#  'м и',
#  'or g',
#  'htt ps',
#  '▁v o',
#  'i ent',
#  'o ve',
#  '▁val ue',
#  'en g',
#  '▁L a',
#  '^ {',
#  're f',
#  'i ed',
#  'E R',
#  '▁st at',
#  'f ig',
#  'm e',
#  '▁v on',
#  '▁in ter',
#  'ro id',
#  'at er',
#  '▁the ir',
#  '▁b et',
#  '▁e in',
#  '} \\',
#  '" >',
#  '▁s ub',
#  '▁o p',
#  '▁d on',
#  't y',
#  '▁tr y',
#  '▁P ro',
#  '▁t ra',
#  '▁s ame',
#  'e p',
#  '▁t wo',
#  '▁n ame',
#  'ol d',
#  'le t',
#  '▁s im',
#  's p',
#  '▁a v',
#  'b re',
#  'ble m',
#  'e y',
#  '▁c ould',
#  '▁c or',
#  '▁a cc',
#  'ay s',
#  'c re',
#  'ur r',
#  's i',
#  '▁con st',
#  'u es',
#  '} $',
#  'V iew',
#  '▁a ct',
#  '▁b o',
#  '▁ ко',
#  '▁s om',
#  '▁ab out',
#  'l and',
#  'm er',
#  '▁l ist',
#  'c al',
#  '▁im port',
#  'c ol',
#  '▁n a',
#  'n a',
#  ': :',
#  '▁wh o',
#  '▁er ror',
#  '▁ X',
#  'at or',
#  'e xt',
#  '▁be en',
#  'é r',
#  '▁r un',
#  'p os',
#  '▁c l',
#  '* *',
#  '▁ К',
#  'ul ar',
#  'au se',
#  '▁re g',
#  '▁kn ow',
#  '▁se e',
#  '▁h im',
#  'n ing',
#  '▁з а',
#  'at es',
#  'f ore',
#  'ion s',
#  '▁h el',
#  'ut e',
#  '▁re m',
#  '▁ го',
#  '▁M ar',
#  'р у',
#  'v ice',
#  'ire ct',
#  'n er',
#  '▁und er',
#  'ri b',
#  'h r',
#  'ч е',
#  '▁A s',
#  '▁ end',
#  'em ber',
#  '▁ а',
#  '▁at t',
#  'in a',
#  's on',
#  '▁fol low',
#  '▁S ch',
#  'pe ct',
#  '▁re l',
#  '▁S o',
#  '▁lo ok',
#  'ab el',
#  '▁pro blem',
#  '▁v an',
#  'str ong',
#  'c o',
#  'p on',
#  'c a',
#  'ad a',
#  '" :',
#  'con d',
#  'am b',
#  '} ,',
#  'qu est',
#  '▁a ut',
#  '▁res ult',
#  '▁m ay',
#  'R e',
#  'htt p',
#  ') :',
#  '▁A nd',
#  're d',
#  '▁H ow',
#  'p o',
#  'с ко',
#  'at t',
#  'ou p',
#  'c ed',
#  '▁t ype',
#  '▁th an',
#  '▁con s',
#  'u f',
#  'ц и',
#  '▁qu estion',
#  'ra ph',
#  'ig h',
#  '▁ М',
#  '▁h tt',
#  'in s',
#  'd en',
#  '▁d a',
#  '▁v er',
#  'o h',
#  '▁= >',
#  'ri v',
#  'u de',
#  '▁F or',
#  '▁ ra',
#  'f rac',
#  'м а',
#  '▁a fter',
#  '} {',
#  '▁m ethod',
#  '" )',
#  'am p',
#  'as h',
#  '▁re c',
#  '▁dif fer',
#  'O N',
#  'a x',
#  'am ent',
#  'our ce',
#  'C on',
#  'it s',
#  'N ame',
#  'm an',
#  '▁be c',
#  'ch e',
#  '▁E n',
#  'a j',
#  '▁g ener',
#  'I N',
#  '▁ id',
#  'ag es',
#  '▁l oc',
#  'f o',
#  'b r',
#  '▁s he',
#  'P ro',
#  '▁un a',
#  '▁ к',
#  'et a',
#  'lo g',
#  'ol og',
#  '▁s ur',
#  'ar g',
#  '▁- -',
#  'k t',
#  '( \\',
#  'm in',
#  '▁l ine',
#  '▁var i',
#  'с я',
#  'ic s',
#  'н я',
#  'ver y',
#  'ad d',
#  '▁ob ject',
#  'I d',
#  '▁B ut',
#  '▁c ase',
#  '▁ma ke',
#  '▁c al',
#  '▁p ass',
#  'с ь',
#  'ess ion',
#  'n et',
#  '. "',
#  '▁ г',
#  'ä r',
#  'д е',
#  'n o',
#  'at ing',
#  'at o',
#  'l ine',
#  'в и',
#  '▁E x',
#  '▁as s',
#  '▁v ers',
#  'л я',
#  '▁ ed',
#  'um n',
#  'oth er',
#  'ст а',
#  'at ive',
#  'S tring',
#  '▁l os',
#  'w n',
#  '▁an swer',
#  '▁le t',
#  '▁p e',
#  'ent s',
#  '▁f e',
#  'in ce',
#  'n i',
#  'id er',
#  'ow s',
#  '▁t est',
#  '▁h ere',
#  'ro ll',
#  '▁c all',
#  'ru ct',
#  '▁p ol',
#  'a it',
#  '▁b ack',
#  'h o',
#  'E x',
#  'r ess',
#  'S T',
#  'ri ed',
#  'd ate',
#  'е т',
#  '▁d id',
#  't ing',
#  '▁E l',
#  '▁de m',
#  ') $',
#  'ов а',
#  'urr ent',
#  'la ce',
#  'r ight',
#  'r en',
#  ...]

# %%
ensure_dir(f'data/llm_tokenizers/{model_name}')
with open(f'data/llm_tokenizers/{model_name}/merges.txt', 'w') as fin:
    fin.write('#version: 0.2\n')
    fin.writelines([m + '\n' for m in cleaned_merges])
